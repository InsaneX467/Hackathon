# %% [markdown]
# # Landslide & Flash-Flood Early Warning System - Exploratory Data Analysis
#
# Dataset: `DataUploader/IndLands` (Hugging Face)
# Model: Support Vector Machine (SVM) Classifier

# %%
from ml.src.data_loader import load_indlands_data, inspect_dataset
df = load_indlands_data(sample_per_state=5000)
inspect_dataset(df)

# %%
from ml.src.feature_engineering import engineer_features
df_engineered = engineer_features(df)
print('Engineered DataFrame Shape:', df_engineered.shape)

# %%
from ml.src.evaluate import print_evaluation_summary
print_evaluation_summary()
